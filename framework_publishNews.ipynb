# %%
import pandas as pd
import IniciarDriver

# %%
#instancia a classe para abrir o driver
#exibe a mensagem caso o driver esteja atualizado ou baixa automaticamente caso não esteja.
abrirDriver = IniciarDriver.ExtracaoPublishNews()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/perolatai/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache

# %%
#método para selecionar o ano, não é necessário passar argumento
abrirDriver.seleciona_anual()

# %%
#método para escolher o ano, necessário passar como argumento o ano escolhido, entre 2010 e 2021 (são os anos dispoíveis no aite)
abrirDriver.seleciona_xpath(2015)

# %%
#coleta os dados e guarda no dataFrame, necessário guardar o dataframe que retorna da classe dentro de uma variavel
dataFrame2015 = abrirDriver.coleta_dados()

# %%
#exibindo o dataframe
dataFrame2015
# Out:
#    posicao                                      titulo  \
# 0        1                              Jardim secreto
# 1        2                          Floresta encantada
# 2        3                                      Philia
# 3        4                             Nada a perder 3
# 4        5                Muito mais que 5inco minutos
# 5        6  Ansiedade - Como enfrentar o mal do século
# 6        7                                        Grey
# 7        8                          O pequeno príncipe
# 8        9                                Eu fico loko
# 9       10                           Não se apega, não
# 10      11                           Não se iluda, não
# 11      12                                  A herdeira
# 12      13                                 Se eu ficar
# 13      14                       A mágica da arrumação
# 14      15                            Morri para viver
# 15      16                            Cidades de papel
# 16      17     Diário de um banana - Caindo na estrada
# 17      18                      O diário de Anne Frank
# 18      19                            Geração de valor
# 19      20                                       Maria
#
#                               autor            editora       categoria  \
# 0                   Johanna Basford           Sextante      Não ficção
# 1                   Johanna Basford           Sextante      Não ficção
# 2               Padre Marcelo Rossi         Principium       Autoajuda
# 3                       Edir Macedo  Planeta do Brasil      Não ficção
# 4                   Kéfera Buchmann           Paralela      Não ficção
# 5                      Augusto Cury            Saraiva       Autoajuda
# 6                       E. L. James         Intrínseca          Ficção
# 7             Antoine Saint-Exupéry               Agir  Infantojuvenil
# 8              Christian Figueiredo      Novas Páginas  Infantojuvenil
# 9                   Isabela Freitas         Intrínseca       Autoajuda
# 10                  Isabela Freitas         Intrínseca       Autoajuda
# 11                       Kiera Cass           Seguinte  Infantojuvenil
# 12                     Gayle Forman      Novo Conceito          Ficção
# 13                      Marie Kondo           Sextante       Autoajuda
# 14                   Andressa Urach  Planeta do Brasil      Não ficção
# 15                       John Green         Intrínseca          Ficção
# 16                      Jeff Kinney         VR Editora  Infantojuvenil
# 17  Mirjam Pressler / Otto H. Frank             Record      Não ficção
# 18          Flávio Augusto da Silva           Sextante        Negócios
# 19                  Rodrigo Alvarez       Globo Livros      Não ficção
#
#              isbn numero de paginas volumes vendidos
# 0   9788543101637                96          719.626
# 1   9788543101958                84          485.222
# 2   9788525060044               136          446.653
# 3   9788542204148               304          316.465
# 4   9788584390113               136          197.461
# 5   9788502218482               160          184.874
# 6   9788580577730               528          174.796
# 7   9788522005239                94          152.276
# 8   9788581636818               160          137.219
# 9   9788580575330               256          135.051
# 10  9788580577686               272          113.988
# 11  9788565765657               360          112.718
# 12  9788581635415               224          100.757
# 13  9788543102092               160           99.846
# 14  9788542205343               240           97.307
# 15  9788580573749               368           94.771
# 16  9788576838234               224           93.015
# 17  9788501044457               352           85.966
# 18  9788543101620               208           82.660
# 19  9788525061515               256           80.925

# %%
#método para salvar o arquivo em excel, necessário passar como parametros o dataframe e um nome para o arquivo
abrirDriver.salvar_dataframe(dataFrame2015, 'dataFrame2015')
